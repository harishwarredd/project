# %%
import pandas as pd

# %%
df_microcreditset=pd.read_csv("micro_credit.csv")
df_microcreditset
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df_microcreditset=df_microcreditset.drop(df_microcreditset.columns[0], axis=1)
df_microcreditset=df_microcreditset.drop(df_microcreditset.columns[34], axis=1)
df_microcreditset["pdate"] = pd.to_datetime(df_microcreditset["pdate"])

# %%
df_microcreditset.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  amnt_loans30  \
# 0                2.0                0.0              1539  ...            12
# 1               20.0                0.0              5787  ...            12
# 2                3.0                0.0              1539  ...             6
# 3               41.0                0.0               947  ...            12
# 4                4.0                0.0              2309  ...            42
#
# ...

# %%
df_microcreditset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
df_microcreditset.isna().sum().plot(kind="bar")
df_microcreditset.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %%
len(pd.unique(df_microcreditset["msisdn"]))
# Out:
# 186243

# %%
df_microcreditset.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
col_names=df_microcreditset.columns
col_names
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pdate'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
ax.boxplot(df_microcreditset["fr_da_rech90"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20803a6a5e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20803a6aca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20803a6a280>],
#  'medians': [<matplotlib.lines.Line2D at 0x20803a723a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20803a726a0>],
#  'means': []}

# %%
df_microcreditset["fr_da_rech90"].min()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
print(sum(df_microcreditset['label']==1))
print(sum(df_microcreditset['label']==0))
len(df_microcreditset.index)
# Out:
# 183431
# 26162
# 209593

# %% [markdown]
# # Data visualization

# %%
import seaborn as sns
g=sns.catplot(x="label",data=df_microcreditset,kind="count",palette="PRGn",alpha=1)
g.set(xlabel="Label",ylabel="Count")
plt.show()

# %% [markdown]
# # Feature selection(Logistic Regression)

# %%
Xsel=df_microcreditset.iloc[:,2:34]
Ysel=df_microcreditset.iloc[:,0]

# %%
from sklearn.datasets import load_digits
from sklearn.feature_selection import SelectKBest, chi2
bestfeatures=SelectKBest(score_func=chi2,k=20)

# %%
Xsel.describe()
# Out:
#                  aon   daily_decr30   daily_decr90       rental30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean     8112.343445    5381.402289    6082.515068    2692.581910
# std     75696.082531    9220.623400   10918.812767    4308.586781
# min       -48.000000     -93.012667     -93.012667  -23737.140000
# 25%       246.000000      42.440000      42.692000     280.420000
# 50%       527.000000    1469.175667    1500.000000    1083.570000
# 75%       982.000000    7244.000000    7802.790000    3356.940000
# max    999860.755168  265926.000000  320630.000000  198926.110000
#
#             rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# count  209593.000000      209593.000000      209593.000000     209593.000000
# mean     3483.406534        3755.847800        3712.202921       2064.452797
# std      5770.461279       53905.892230       53374.833430       2370.786034
# ...

# %%
def remove_negs(Xsel):
    for item in Xsel:
        if item<0:
            Xsel.remove(item)

# %%
  print(Xsel)
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 209588   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# ...

# %%
Xsel.describe()
# Out:
#                  aon   daily_decr30   daily_decr90       rental30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean     8112.343445    5381.402289    6082.515068    2692.581910
# std     75696.082531    9220.623400   10918.812767    4308.586781
# min       -48.000000     -93.012667     -93.012667  -23737.140000
# 25%       246.000000      42.440000      42.692000     280.420000
# 50%       527.000000    1469.175667    1500.000000    1083.570000
# 75%       982.000000    7244.000000    7802.790000    3356.940000
# max    999860.755168  265926.000000  320630.000000  198926.110000
#
#             rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# count  209593.000000      209593.000000      209593.000000     209593.000000
# mean     3483.406534        3755.847800        3712.202921       2064.452797
# std      5770.461279       53905.892230       53374.833430       2370.786034
# ...

# %%
def remove_negs(Xsel):
    for item in Xsel:
        if item<0:
            Xsel.remove(item)

# %%
Xsel
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 209588   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# ...

# %%
fit=bestfeatures.fit(Xsel,Ysel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-80c4a4d614ee> in <module>
# ----> 1 fit=bestfeatures.fit(Xsel,Ysel)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     351
#     352         self._check_params(X, y)
# --> 353         score_func_ret = self.score_func(X, y)
#     354         if isinstance(score_func_ret, (list, tuple)):
#     355             self.scores_, self.pvalues_ = score_func_ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in chi2(X, y)
#     215     X = check_array(X, accept_sparse='csr')
#     216     if np.any((X.data if issparse(X) else X) < 0):
# --> 217         raise ValueError("Input X must be non-negative.")
#     218
#     219     Y = LabelBinarizer().fit_transform(y)
#
# ...

# %%
colnames=["label","sumamnt_ma_rech90","daily_decr90","sumamnt_ma_rech30","daily_decr30","rental90","medianamnt_ma_rech30","last_rech_amt_ma","medianamnt_ma_rech90","rental30","medianmarechprebal30","aon","medianmarechprebal90","amnt_loans90","cnt_da_rech30","amnt_loans30","cnt_ma_rech90","cnt_ma_rech30","last_rech_date_ma","fr_ma_rech30","fr_ma_rech90"]
len(colnames)
# Out:
# 21

# %%
hist = df_microcreditset.iloc[:,0:12].hist()

# %%
hist = df_microcreditset.iloc[:,12:25].hist()

# %%
hist = df_microcreditset.iloc[:,25:35].hist()

# %%
df_microcreditset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
### Filter dataframe to use only important features
df=df_microcreditset[colnames]   #includes Target variable "Label"
df1=df.iloc[:,1:]   #does not include Target variable "Label"
df1.head()
# Out:
#    sumamnt_ma_rech90  daily_decr90  sumamnt_ma_rech30  daily_decr30  rental90  \
# 0               3078   3065.150000             3078.0   3055.050000    260.13
# 1               5787  12124.750000             5787.0  12122.000000   3691.26
# 2               1539   1398.000000             1539.0   1398.000000    900.13
# 3                947     21.228000                0.0     21.228000    159.42
# 4              23496    150.619333            20029.0    150.619333   1098.90
#
#    medianamnt_ma_rech30  last_rech_amt_ma  medianamnt_ma_rech90  rental30  \
# 0                1539.0              1539                1539.0    220.13
# 1                5787.0              5787                5787.0   3691.26
# 2                1539.0              1539                1539.0    900.13
# 3                   0.0               947                 947.0    159.42
# 4                2309.0              2309                2888.0   1098.90
#
# ...

# %% [markdown]
# # Normalizing data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(df1) 
df1.loc[:,:] = scaled_values

# %% [markdown]
# # Define the independent and dependent variables

# %% [markdown]
# # Build Models

# %%
X_train, X_test, Y_train, Y_test=model_selection.train_test_split(X, Y, test_size = 0.3, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-d1dec43c894d> in <module>
# ----> 1 X_train, X_test, Y_train, Y_test=model_selection.train_test_split(X, Y, test_size = 0.3, random_state = 0)
#
# NameError: name 'model_selection' is not defined

# %%
# logistic regression object 
lr = LogisticRegression(solver='lbfgs', max_iter=400) 
  
# train the model on train set 
lr.fit(X_train, y_train.ravel()) 
  
predictions = lr.predict(X_test) 
  
# print classification report 
print(classification_report(y_test, predictions))

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1))) 
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0))) 
  
# import SMOTE module from imblearn library 
# pip install imblearn (if you don't have imblearn in your system) 
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 2) 
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel()) 
  
print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape)) 
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape)) 
  
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1))) 
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))

# %%
lr1 = LogisticRegression(solver='lbfgs', max_iter=400) 
lr1.fit(X_train_res, Y_train_res.ravel()) 
predictions = lr1.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-73895c093f53> in <module>
# ----> 1 lr1 = LogisticRegression(solver='lbfgs', max_iter=400)
#       2 lr1.fit(X_train_res, Y_train_res.ravel())
#       3 predictions = lr1.predict(X_test)
#
# NameError: name 'LogisticRegression' is not defined

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test,predictions))
print(classification_report(Y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-f5f0981d9203> in <module>
#       1 from sklearn.metrics import classification_report, confusion_matrix
# ----> 2 print(confusion_matrix(Y_test,predictions))
#       3 print(classification_report(Y_test,predictions))
#
# NameError: name 'Y_test' is not defined

# %%
metrics.plot_roc_curve(lr1, X_test, y_test) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-3bc236fe1987> in <module>
# ----> 1 metrics.plot_roc_curve(lr1, X_test, y_test)
#       2 plt.show()
#
# NameError: name 'metrics' is not defined
